# %% [markdown]
# ### Import library
# Nous allons importer les bibliothèque numpy et pandas qui sont necessaire pour le traitement.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import Data
# Nous allons importer les données depuis le répertoire RAwData pour enfin les traiter et transformer

# %%
n=['TimesTamp', 'ECP', 'Antenna', 'RSSI','Channel','Address']
p='../1-RawData/datasetfinale/cible_parasites/25/droitebas-cible-avec-parasites-p25__02-11-2020_16h_55m_14s.csv'
d=','
def importData(path, delimit,cols):
    return pd.read_csv(path, sep=delimit,names=cols)

data=importData(p,d,n)
data = data.drop([0],axis=0) #Suppression de la 1ere ligne
data = data.drop([1],axis=0) #Suppression de la 1ere ligne
data = data.drop([2],axis=0) #Suppression de la 1ere 
data = data.drop(['Channel'],axis=1) #Suppression de la 1ere 
data = data.drop(['Address'],axis=1) #Suppression de la 1ere 
data['FP']=0
data.head(5)
# Out:
#           TimesTamp                       ECP Antenna   RSSI  FP
# 3  1581427753033891  E28068900000000018345317       1  -60.5   0
# 4  1581427753054162  E28068900000000018345317       1    -60   0
# 5  1581427753269703  E28068900000000018345317       1    -60   0
# 6  1581427753298921  E28068900000000018345317       1  -59.5   0
# 7  1581427753513094  E28068900000000018345317       1  -59.5   0

# %% [markdown]
# ### TYPAGE DES CHAMPS
# Nos allons typer les différentes colonnes du dataSet avec les types primaires de python

# %%
def typage(data):
    data['ECP']=data['ECP'].astype(str)
    data['TimesTamp']=data['TimesTamp'].astype('int64')
    data['RSSI']=data['RSSI'].astype('float64')
    data['Antenna']=data['Antenna'].astype('int64')
    data['FP']=data['FP'].astype('int64')
    return data

data=typage(data)
data.info()
data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414 entries, 3 to 416
# Data columns (total 5 columns):
# TimesTamp    414 non-null int64
# ECP          414 non-null object
# Antenna      414 non-null int64
# RSSI         414 non-null float64
# FP           414 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 19.4+ KB
# (414, 5)

# %%
'''
3005FB63AC1F3681EC880468, 1532AC20AC1F3681EC880468, 0000FB63AC1F3681EC880468, 1007FB63AC1F3681EC880468
'''
def deleteRowByECP(datas, ecp):
    print('firstSize', datas.size)
    datas=datas[datas.ECP!=ecp]
    print('secondSize', datas.size)
    return datas

data = deleteRowByECP(data,'3005FB63AC1F3681EC880468')
data = deleteRowByECP(data,'1532AC20AC1F3681EC880468')
data = deleteRowByECP(data,'0000FB63AC1F3681EC880468')
data = deleteRowByECP(data,'1007FB63AC1F3681EC880468')
# Out:
# firstSize 2070
# secondSize 1905
# firstSize 1905
# secondSize 1905
# firstSize 1905
# secondSize 1765
# firstSize 1765
# secondSize 1655

# %%
parasites = ['3025AB20CA1F3681CF101116','3025AB20CA1F3681CF10111B','90134BC1F1CE3781AEA1000A',
'90134BC1F1CE3781AEA10009','E2806890000000001834545B','E28068900000000018345DFC',
'E28068900000000018345317','90134BC1F1CE3781AEA10012','9014FB63AC1F3681EC880901',
'90134BC1F1CE3781AEA10023','E2806890000000001834545C', '90134BC1F1CE3781AEA10021',
'90144BC1F1CE3681EA880912','90134BC1F1CE3781AEA10025','3025AB20CA1F3681CF101119',
'E28068900000000018344E55','E28068900000000018344F88', 'E28068900000000018344F9A',
'E28068900000000018344F87','E28068900000000018344AC4','E2806890000000001834580B',
'90134BC1F1CE3781AEA10002','3025AB20CA1F3681CF10111A','E28068900000000018345944',
'E28068900000000018345804','E28068900000000018344E66','E28068900000000018345329',
'E28068900000000018345CD5','E28068900000000018344F93','E2806890000000001834580A',
'4001FBCAAC1F3690ED880512','90134BC1F1CE3781AEA1001A', '300000000000000000017868', 
'30000000000000000001786C', '30000000000000000001786E', '300000000000000000017866', 
'30000000000000000001786D', '30000000000000000001786A', '300000000000000000017865', 
'300000000000000000017863', '3000000000000000000178BE', 'E28068900000000018345CCE',
'3025AB20CA1F3681CF101118','3025AB20CA1F3681CF10111D','E28068900000000018345455',
'90134BC1F1CE3781AEA1000F','E28068900000000018345CD4']
print(len(parasites))
parasites=list(set(parasites))
print(len(parasites))
data.shape
# Out:
# 47
# 47
# (331, 5)

# %%
def objectExist (objecttag,listofparasites): 
    for dp in listofparasites:
        if(objecttag==dp):
            return True
    return False
def setFalsePositive(fp_list, dataSet):
    lp=[]
    for dp in dataSet.values:
        #print("the tag is:" +dp[1])
        if objectExist(dp[1],fp_list)==True:
            dp[4]=1
            print("the tag is  PARASITE :" +dp[1])

            lp.append(dp) 
        else :
            print("the tag is not parasite :" +dp[1])
            lp.append(dp)    
    l=lp
    
    df=pd.DataFrame(l, columns=['TimesTamp', 'ECP', 'Antenna', 'RSSI','FP'])
    return df

dfp= setFalsePositive(parasites,data)
dfp
# Out:
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is not parasite :2005FB63AC1F3681AB1004E3
# the tag is not parasite :E2806890000000001834498A
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is not parasite :2005FB63AC1F3681AB1004E3
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is not parasite :2005FB63AC1F3681AB1004E3
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is not parasite :2005FB63AC1F3681AB1004E3
# the tag is  PARASITE :E28068900000000018345317
# the tag is not parasite :3005FB63AC1F3681EC8814A0
# the tag is not parasite :3005FB63AC1F3681EC8814A8
# the tag is not parasite :2005FB63AC1F3681AB1004E3
# the tag is  PARASITE :E28068900000000018345317
# the tag is not parasite :3005FB63AC1F3681EC8814A0
# the tag is not parasite :3005FB63AC1F3681EC8814A8
# the tag is not parasite :2005FB63AC1F3681AB1004E3
# the tag is not parasite :3005FB63AC1F3681EC881448
# the tag is not parasite :3005FB63AC1F3681EC8813AD
# the tag is not parasite :3005FB63AC1F3681EC881448
# the tag is not parasite :3005FB63AC1F3681EC8813AD
# the tag is not parasite :3005FB63AC1F3681EC8813AD
# the tag is not parasite :3005FB63AC1F3681EC881448
# the tag is not parasite :E28068900000000018344AC5
# the tag is not parasite :3025AB20CA1F3681CF101115
# the tag is not parasite :7336CEF1C1FE3682DEA1004F
# the tag is not parasite :7336CEF1C1FE3682DEA10049
# the tag is not parasite :3025AB20CA1F3681CF101115
# the tag is not parasite :3005FB63AC1F3681EC8813AD
# the tag is not parasite :3005FB63AC1F3681EC881448
# the tag is not parasite :7336CEF1C1FE3682DEA1004F
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is not parasite :3005FB63AC1F3681EC8814A0
# the tag is  PARASITE :E28068900000000018345317
# the tag is not parasite :2005FB63AC1F3681AB1004E3
# the tag is not parasite :3005FB63AC1F3681EC8814A8
# the tag is not parasite :2005FB63EAC13681E5C6028D
# the tag is not parasite :2005FB63EAC13681E4EC0F4B
# the tag is not parasite :3005FB63AC1F3681EC8814A8
# the tag is not parasite :2005FB63AC1F3681AB1004E3
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is  PARASITE :E28068900000000018345317
# the tag is not parasite :3005FB63AC1F3681EC8814A0
# the tag is not parasite :3005FB63AC1F3681EC881448
# the tag is not parasite :3005FB63AC1F3681EC881318
# the tag is not parasite :90134BC1F1CE3781AEA1000B
# the tag is not parasite :3005FB63AC1F3681EC8805A9
# the tag is not parasite :3005FB63AC1F3681EC8813AD
# the tag is not parasite :1532FB63AC1F3681EC880468
# the tag is not parasite :E28068900000000018343766
# the tag is  PARASITE :3025AB20CA1F3681CF101118
# the tag is not parasite :7336CEF1C1FE3682DEA1005C
# the tag is not parasite :3005FB63AC1F3681EC881448
# the tag is not parasite :1532FB63AC1F3681EC880468
# the tag is not parasite :3005FB63AC1F3681EC881318
# the tag is not parasite :3005FB63AC1F3681EC8805A9
# the tag is not parasite :3005FB63AC1F3681EC8813AD
# the tag is not parasite :E28068900000000018343766
# the tag is  PARASITE :3025AB20CA1F3681CF101118
# the tag is not parasite :2005FB63EAC13681E5C6028D
# the tag is not parasite :3005FB63AC1F3681EC88145A
# the tag is not parasite :3005FB63AC1F3681EC8805A5
# the tag is not parasite :3005FB63AC1F3681EC8813AD
# the tag is not parasite :3005FB63AC1F3681EC8814A8
# the tag is not parasite :E28068900000000018343632
# the tag is not parasite :E28068900000000018343FE2
# the tag is not parasite :3005FB63AC1F3681EC881490
# the tag is not parasite :3005FB63AC1F3681EC8814A0
# the tag is not parasite :3005FB63AC1F3681EC88141F
# the tag is not parasite :2005FB63EAC13681E4EC0F4F
# the tag is not parasite :E28068900000000018343B11
# the tag is not parasite :3005FB63AC1F3681EC881378
# the tag is not parasite :3005FB63AC1F3681EC881318
# the tag is not parasite :E28068900000000018343B17
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is not parasite :2005FB63EAC13681E5C602B6
# the tag is not parasite :3005FB63AC1F3681EC881448
# the tag is not parasite :E28068900000000018343B18
# the tag is not parasite :E280689000000000183444A4
# the tag is not parasite :3005FB63AC1F3681EC881316
# the tag is not parasite :3005FB63AC1F3681EC881166
# the tag is not parasite :E28068900000000018343633
# the tag is not parasite :2005FB63EAC13681E4EC0F4B
# the tag is not parasite :3005FB63AC1F3681EC8811B5
# the tag is not parasite :E28068900000000018343766
# the tag is not parasite :3005FB63AC1F3681EC881458
# the tag is not parasite :E28068900000000018342CA3
# the tag is not parasite :E2806890000000001834316C
# the tag is not parasite :2005FB63AC1F3681AB1004E3
# the tag is not parasite :E28068900000000018343C51
# the tag is not parasite :3005FB63AC1F3681EC88129C
# the tag is not parasite :3005FB63AC1F3681EC88131E
# the tag is not parasite :3005FB63AC1F3681EC8805A9
# the tag is not parasite :2005FB63EAC13681E4EC0F50
# the tag is not parasite :E28068900000000018343B23
# the tag is not parasite :E2806890000000001834329F
# the tag is not parasite :E28068900000000018342CA4
# the tag is not parasite :E28068900000000018343FE3
# the tag is not parasite :3005FB63AC1F3681EC88134B
# the tag is not parasite :2005FB63EAC13681E4EC0F4C
# the tag is not parasite :3005FB63AC1F3681EC8805AA
# the tag is not parasite :E28068900000000018343FEE
# the tag is not parasite :E28068900000000018344120
# the tag is not parasite :E280689000000000183432A0
# the tag is not parasite :3005FB63AC1F3681EC8811B0
# the tag is not parasite :90144BC1F1CE3681EA880811
# the tag is not parasite :E2806890000000001834316B
# the tag is not parasite :E2806890000000001834362C
# the tag is not parasite :E28068900000000018343C52
# the tag is not parasite :E28068900000000018343C4B
# the tag is not parasite :3005FB63AC1F3681EC88143C
# the tag is not parasite :2005FB63EAC13681E5C602A1
# the tag is not parasite :E28068900000000018343767
# the tag is not parasite :E28068900000000018343760
# the tag is not parasite :E28068900000000018343C5D
# the tag is not parasite :E28068900000000018344115
# the tag is not parasite :2005FB63EAC13681E5C6027B
# the tag is not parasite :7336CEF1C1FE3682DEA10046
# the tag is not parasite :E28068900000000018344994
# the tag is not parasite :3005FB63AC1F3681EC881490
# the tag is not parasite :E28068900000000018343C4B
# the tag is not parasite :3005FB63AC1F3681EC8813AD
# the tag is not parasite :2005FB63EAC13681E4EC0F4B
# the tag is not parasite :3005FB63AC1F3681EC881458
# the tag is not parasite :3005FB63AC1F3681EC88145A
# the tag is not parasite :3005FB63AC1F3681EC88129C
# the tag is not parasite :E28068900000000018343B17
# the tag is not parasite :E28068900000000018343C5D
# the tag is not parasite :E28068900000000018343C51
# the tag is not parasite :3005FB63AC1F3681EC881316
# the tag is not parasite :3005FB63AC1F3681EC881318
# the tag is not parasite :2005FB63EAC13681E5C6028D
# the tag is not parasite :2005FB63EAC13681E4EC0F4C
# the tag is not parasite :E2806890000000001834362C
# the tag is not parasite :3005FB63AC1F3681EC881166
# the tag is not parasite :3005FB63AC1F3681EC8814A0
# the tag is not parasite :E280689000000000183432A0
# the tag is not parasite :E28068900000000018342CA4
# the tag is not parasite :3005FB63AC1F3681EC88134B
# the tag is not parasite :E2806890000000001834316B
# the tag is not parasite :E28068900000000018343632
# the tag is not parasite :2005FB63EAC13681E4EC0F4F
# the tag is not parasite :3005FB63AC1F3681EC881378
# the tag is not parasite :2005FB63EAC13681E4EC0F50
# the tag is not parasite :E28068900000000018343FE3
# the tag is not parasite :E28068900000000018343B11
# the tag is not parasite :3005FB63AC1F3681EC88141F
# the tag is not parasite :3005FB63AC1F3681EC8805A5
# the tag is not parasite :E28068900000000018343767
# the tag is not parasite :E28068900000000018343633
# the tag is not parasite :3005FB63AC1F3681EC8814A8
# the tag is not parasite :E28068900000000018343B18
# the tag is not parasite :3005FB63AC1F3681EC88131E
# the tag is not parasite :3005FB63AC1F3681EC8811B0
# the tag is not parasite :3005FB63AC1F3681EC8805A9
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is not parasite :3005FB63AC1F3681EC8811B5
# the tag is not parasite :3005FB63AC1F3681EC881448
# the tag is not parasite :3005FB63AC1F3681EC88143C
# the tag is not parasite :E28068900000000018343766
# the tag is not parasite :E28068900000000018343C52
# the tag is not parasite :2005FB63AC1F3681AB1004E3
# the tag is not parasite :E28068900000000018343760
# the tag is not parasite :E2806890000000001834316C
# the tag is not parasite :3005FB63AC1F3681EC8805AA
# the tag is not parasite :E28068900000000018343FEE
# the tag is not parasite :E280689000000000183444A4
# the tag is not parasite :E28068900000000018343B23
# the tag is not parasite :E28068900000000018342CA3
# the tag is not parasite :E2806890000000001834329F
# the tag is not parasite :2005FB63EAC13681E5C602A1
# the tag is not parasite :90144BC1F1CE3681EA880811
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is not parasite :2005FB63EAC13681E4EC0F4F
# the tag is not parasite :3005FB63AC1F3681EC88145A
# the tag is not parasite :3005FB63AC1F3681EC881318
# the tag is not parasite :3005FB63AC1F3681EC881166
# the tag is not parasite :3005FB63AC1F3681EC8811B5
# the tag is not parasite :3005FB63AC1F3681EC88134B
# the tag is not parasite :3005FB63AC1F3681EC881448
# the tag is not parasite :2005FB63EAC13681E4EC0F4B
# the tag is not parasite :3005FB63AC1F3681EC88155C
# the tag is not parasite :2005FB63EAC13681E4EC0F50
# the tag is not parasite :3005FB63AC1F3681EC881458
# the tag is not parasite :2005FB63AC1F3681AB10052A
# the tag is not parasite :3005FB63AC1F3681EC881378
# the tag is not parasite :3005FB63AC1F3681EC8805A5
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is not parasite :3005FB63AC1F3681EC8813AD
# the tag is not parasite :3005FB63AC1F3681EC8811B0
# the tag is not parasite :3005FB63AC1F3681EC8805A9
# the tag is  PARASITE :3025AB20CA1F3681CF101118
# the tag is not parasite :E28068900000000018344AC5
# the tag is not parasite :3005FB63AC1F3681EC8805AA
# the tag is not parasite :2005FB63EAC13681E4EC0F4B
# the tag is not parasite :3005FB63AC1F3681EC8805A9
# the tag is not parasite :3005FB63AC1F3681EC881378
# the tag is not parasite :3005FB63AC1F3681EC8811B0
# the tag is not parasite :3005FB63AC1F3681EC8813AD
# the tag is not parasite :3005FB63AC1F3681EC88134B
# the tag is not parasite :3005FB63AC1F3681EC8805A5
# the tag is not parasite :3005FB63AC1F3681EC881318
# the tag is not parasite :3005FB63AC1F3681EC881458
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is not parasite :2005FB63EAC13681E4EC0F4F
# the tag is not parasite :3005FB63AC1F3681EC881166
# the tag is not parasite :3005FB63AC1F3681EC88145A
# the tag is not parasite :3005FB63AC1F3681EC881448
# the tag is not parasite :2005FB63EAC13681E4EC0F50
# the tag is not parasite :2005FB63AC1F3681AB10052A
# the tag is not parasite :3005FB63AC1F3681EC88155C
# the tag is not parasite :3005FB63AC1F3681EC8811B5
# the tag is not parasite :E28068900000000018344AC5
# the tag is not parasite :3005FB63AC1F3681EC881318
# the tag is not parasite :3005FB63AC1F3681EC881316
# the tag is not parasite :3005FB63AC1F3681EC881448
# the tag is not parasite :3005FB63AC1F3681EC88134B
# the tag is not parasite :3005FB63AC1F3681EC881378
# the tag is not parasite :3005FB63AC1F3681EC881166
# the tag is not parasite :3005FB63AC1F3681EC88132C
# the tag is not parasite :3005FB63AC1F3681EC881458
# the tag is not parasite :3005FB63AC1F3681EC8811B5
# the tag is not parasite :2005FB63EAC13681E4EC0F4B
# the tag is not parasite :3005FB63AC1F3681EC8811B0
# the tag is not parasite :2005FB63EAC13681E5C6028D
# the tag is not parasite :3005FB63AC1F3681EC881490
# the tag is not parasite :3005FB63AC1F3681EC8805A9
# the tag is not parasite :2005FB63EAC13681E5C602A1
# the tag is not parasite :3005FB63AC1F3681EC88155C
# the tag is not parasite :3005FB63AC1F3681EC8805A5
# the tag is not parasite :3005FB63AC1F3681EC881317
# the tag is not parasite :2005FB63EAC13681E5C6025A
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is not parasite :2005FB63EAC13681E4EC0F50
# the tag is not parasite :2005FB63AC1F3681AB1004E3
# the tag is not parasite :3005FB63AC1F3681EC8805AA
# the tag is not parasite :2005FB63EAC13681E4EC0F4F
# the tag is not parasite :3005FB63AC1F3681EC8814B6
# the tag is not parasite :3005FB63AC1F3681EC881166
# the tag is not parasite :3005FB63AC1F3681EC8811B0
# the tag is not parasite :3005FB63AC1F3681EC881316
# the tag is not parasite :3005FB63AC1F3681EC881490
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is not parasite :3005FB63AC1F3681EC8811B5
# the tag is not parasite :3005FB63AC1F3681EC881378
# the tag is not parasite :3005FB63AC1F3681EC881458
# the tag is not parasite :3005FB63AC1F3681EC881318
# the tag is not parasite :2005FB63EAC13681E5C6028D
# the tag is not parasite :2005FB63EAC13681E5C6025A
# the tag is not parasite :3005FB63AC1F3681EC8805A5
# the tag is not parasite :3005FB63AC1F3681EC88134B
# the tag is not parasite :2005FB63EAC13681E4EC0F50
# the tag is not parasite :2005FB63EAC13681E5C602A1
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is not parasite :2005FB63EAC13681E5C6028D
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is not parasite :3005FB63AC1F3681EC8814BC
# the tag is not parasite :3005FB63AC1F3681EC881318
# the tag is not parasite :1007CEA7AC1F3681EAC5106D
# the tag is not parasite :3005FB63AC1F3681EC8811B0
# the tag is not parasite :3005FB63AC1F3681EC881490
# the tag is not parasite :E28068900000000018344AC5
# the tag is not parasite :3005FB63AC1F3681EC881316
# the tag is not parasite :3005FB63AC1F3681EC8812DB
# the tag is not parasite :3005FB63AC1F3681EC8805A9
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is not parasite :3005FB63AC1F3681EC881318
# the tag is not parasite :E28068900000000018344AC5
# the tag is not parasite :3005FB63AC1F3681EC8811B0
# the tag is not parasite :3005FB63AC1F3681EC881490
# the tag is not parasite :3005FB63AC1F3681EC8814BC
# the tag is not parasite :1007CEA7AC1F3681EAC5106D
# the tag is not parasite :3005FB63AC1F3681EC881318
# the tag is not parasite :3005FB63AC1F3681EC881318
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is not parasite :E28068900000000018344AC5
# the tag is not parasite :E28068900000000018344AC5
# the tag is not parasite :3005FB63AC1F3681EC88149C
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is not parasite :E28068900000000018344AC5
# the tag is not parasite :E28068900000000018344AC5
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
# the tag is  PARASITE :E28068900000000018345317
#             TimesTamp                       ECP  Antenna  RSSI  FP
# 0    1581427753033891  E28068900000000018345317        1 -60.5   1
# 1    1581427753054162  E28068900000000018345317        1 -60.0   1
# 2    1581427753269703  E28068900000000018345317        1 -60.0   1
# 3    1581427753298921  E28068900000000018345317        1 -59.5   1
# 4    1581427753513094  E28068900000000018345317        1 -59.5   1
# 5    1581427753544895  E28068900000000018345317        1 -59.5   1
# 6    1581427753748230  E28068900000000018345317        1 -59.5   1
# 7    1581427753775459  E28068900000000018345317        1 -59.5   1
# 8    1581427753983658  E28068900000000018345317        1 -59.5   1
# 9    1581427754008097  E28068900000000018345317        1 -59.0   1
# 10   1581427754217635  E28068900000000018345317        1 -59.0   1
# 11   1581427754245189  E28068900000000018345317        1 -59.5   1
# 12   1581427754453880  E28068900000000018345317        1 -59.5   1
# 13   1581427754485146  E28068900000000018345317        1 -59.0   1
# 14   1581427754712161  E28068900000000018345317        1 -59.0   1
# 15   1581427754740595  E28068900000000018345317        1 -59.5   1
# 16   1581427754961418  E28068900000000018345317        1 -60.0   1
# 17   1581427754992248  E28068900000000018345317        1 -59.5   1
# 18   1581427755197357  E28068900000000018345317        1 -60.5   1
# 19   1581427755224960  E28068900000000018345317        1 -60.0   1
# 20   1581427755444303  E28068900000000018345317        1 -62.0   1
# 21   1581427755471813  E28068900000000018345317        1 -62.5   1
# 22   1581427755924316  E28068900000000018345317        1 -63.0   1
# 23   1581427755956982  E28068900000000018345317        1 -63.0   1
# 24   1581427756182039  3005FB63AC1F3681EC88149C        1 -59.0   0
# 25   1581427756188454  2005FB63AC1F3681AB1004E3        1 -61.0   0
# 26   1581427756198394  E2806890000000001834498A        1 -68.0   0
# 27   1581427756208994  3005FB63AC1F3681EC88149C        1 -57.5   0
# 28   1581427756222385  2005FB63AC1F3681AB1004E3        1 -60.5   0
# 29   1581427756435631  3005FB63AC1F3681EC88149C        1 -61.5   0
# ..                ...                       ...      ...   ...  ..
# 301  1581427758795133  E28068900000000018345317        1 -60.0   1
# 302  1581427758847334  3005FB63AC1F3681EC88149C        2 -62.5   0
# 303  1581427758853322  E28068900000000018344AC5        2 -69.5   0
# 304  1581427758884850  E28068900000000018344AC5        2 -69.0   0
# 305  1581427758896478  3005FB63AC1F3681EC88149C        2 -61.5   0
# 306  1581427759046305  E28068900000000018345317        1 -60.0   1
# 307  1581427759071064  E28068900000000018345317        1 -59.5   1
# 308  1581427759104001  E28068900000000018344AC5        2 -65.0   0
# 309  1581427759131308  E28068900000000018344AC5        2 -66.0   0
# 310  1581427759293633  E28068900000000018345317        1 -60.0   1
# 311  1581427759320625  E28068900000000018345317        1 -60.0   1
# 312  1581427759544853  E28068900000000018345317        1 -60.0   1
# 313  1581427759574568  E28068900000000018345317        1 -59.5   1
# 314  1581427759788846  E28068900000000018345317        1 -60.0   1
# 315  1581427759811502  E28068900000000018345317        1 -60.0   1
# 316  1581427760028010  E28068900000000018345317        1 -60.0   1
# 317  1581427760055375  E28068900000000018345317        1 -60.0   1
# 318  1581427760263504  E28068900000000018345317        1 -59.5   1
# 319  1581427760284904  E28068900000000018345317        1 -60.0   1
# 320  1581427760500074  E28068900000000018345317        1 -60.0   1
# 321  1581427760525532  E28068900000000018345317        1 -60.0   1
# 322  1581427760852754  E28068900000000018345317        1 -60.0   1
# 323  1581427760874232  E28068900000000018345317        1 -60.0   1
# 324  1581427761084003  E28068900000000018345317        1 -59.5   1
# 325  1581427761113695  E28068900000000018345317        1 -60.0   1
# 326  1581427761310630  E28068900000000018345317        1 -60.0   1
# 327  1581427761330548  E28068900000000018345317        1 -60.0   1
# 328  1581427761549637  E28068900000000018345317        1 -59.5   1
# 329  1581427761577371  E28068900000000018345317        1 -60.0   1
# 330  1581427761791794  E28068900000000018345317        1 -60.0   1
#
# [331 rows x 5 columns]

# %% [markdown]
# ### Export Data
# Nous allons sauvegarder les donées dans un fichier .csv

# %%
import time
def exportData(data, path):
    data.to_csv(path, index = None, header=False)

# %%
path='../2-TransformedData/DerriereGaucheBas-p30__02-11-2020_15h_05m_20s.csv'
exportData(data, path)
