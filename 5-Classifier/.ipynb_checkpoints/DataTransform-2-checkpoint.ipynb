# %% [markdown]
# ### Import library
# Nous allons importer les bibliothèque numpy et pandas qui sont necessaire pour le traitement.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import Data
# Nous allons importer les données depuis le répertoire RAwData pour enfin les traiter et transformer

# %%
n=['TimesTamp', 'ECP', 'Antenna', 'RSSI', 'Channel', 'Adress']
p='../1-RawData/P30.csv'
d=','
def importData(path, delimit,cols):
    return pd.read_csv(path, sep=delimit,names=cols)

data=importData(p,d,n)
data = data.drop([0],axis=0) #Suppression de la 1ere ligne
data.head(5)
# Out:
#           TimesTamp                       ECP Antenna   RSSI Channel  \
# 1  1581079415482429  30000000000000000001785C       1    -55   865.7
# 2  1581079415484133  300000000000000000017857       1  -60.5   865.7
# 3  1581079415486862              245390003866       1    -67   865.7
# 4  1581079415507659  30000000000000000001785C       1    -55   865.7
# 5  1581079415508791  300000000000000000017857       1  -60.5   865.7
#
#          Adress
# 1  192.168.0.10
# 2  192.168.0.10
# 3  192.168.0.10
# 4  192.168.0.10
# 5  192.168.0.10

# %% [markdown]
# ### TYPAGE DES CHAMPS
# Nos allons typer les différentes colonnes du dataSet avec les types primaires de python

# %%
def typage(data):
    data['ECP']=data['ECP'].astype(str)
    data['TimesTamp']=data['TimesTamp'].astype('int64')
    data['RSSI']=data['RSSI'].astype('float64')
    data['Antenna']=data['Antenna'].astype('int64')
    return data

data=typage(data)
data.info()
data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7122 entries, 1 to 7122
# Data columns (total 6 columns):
# TimesTamp    7122 non-null int64
# ECP          7122 non-null object
# Antenna      7122 non-null int64
# RSSI         7122 non-null float64
# Channel      7122 non-null object
# Adress       7122 non-null object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 709.5+ KB
# (7122, 6)

# %%
data.ECP = data.ECP.values+"1"
data.head(10)
# Out:
#              TimesTamp                         ECP  Antenna  RSSI Channel  \
# 1     1581079415482429  30000000000000000001785C11        1 -55.0   865.7
# 2     1581079415484133  30000000000000000001785711        1 -60.5   865.7
# 3     1581079415486862              24539000386611        1 -67.0   865.7
# 4     1581079415507659  30000000000000000001785C11        1 -55.0   865.7
# 5     1581079415508791  30000000000000000001785711        1 -60.5   865.7
# 6     1581079415511981              24539000386611        1 -67.0   865.7
# 7     1581079415543721  30000000000000000001785711        2 -59.5   865.7
# 8     1581079415546450  30000000000000000001788511        2 -52.0   865.7
# 9     1581079415548796              24539000386811        2 -68.5   865.7
# 10    1581079415550258  30000000000000000001785C11        2 -52.0   865.7
# 11    1581079415575038              24539000386811        2 -69.5   865.7
# 12    1581079415576657  30000000000000000001785C11        2 -52.0   865.7
# 13    1581079415578242  30000000000000000001785711        2 -59.5   865.7
# 14    1581079415582514  30000000000000000001788511        2 -52.0   865.7
# 15    1581079415616292              24539000386811        3 -64.0   865.7
# 16    1581079415618576  30000000000000000001785C11        3 -50.0   865.7
# 17    1581079415622397  30000000000000000001785A11        3 -63.0   865.7
# 18    1581079415636640  30000000000000000001786111        3 -65.5   865.7
# 19    1581079415659257  30000000000000000001785A11        3 -63.0   865.7
# 20    1581079415660397  30000000000000000001785C11        3 -50.0   865.7
# 21    1581079415661358              24539000386811        3 -63.5   865.7
# 22    1581079415687121  30000000000000000001786111        3 -65.5   865.7
# 23    1581079415705876  30000000000000000001785711        4 -59.5   865.7
# 24    1581079415707199  30000000000000000001785C11        4 -51.0   865.7
# 25    1581079415733912  30000000000000000001786911        4 -67.0   865.7
# 26    1581079415753793  30000000000000000001785C11        4 -51.0   865.7
# 27    1581079415755497  30000000000000000001785711        4 -59.0   865.7
# 28    1581079415774739  30000000000000000001786911        4 -67.0   865.7
# 29    1581079415801757              24539000386611        1 -66.0   865.7
# 30    1581079415803448  30000000000000000001785C11        1 -55.0   865.7
# ...                ...                         ...      ...   ...     ...
# 7093  1581079398465716  30000000000000000001785711        1 -62.0   865.7
# 7094  1581079398492620  30000000000000000001785C11        1 -54.5   865.7
# 7095  1581079398494097              24539000386611        1 -68.0   865.7
# 7096  1581079398496826  30000000000000000001785711        1 -61.0   865.7
# 7097  1581079398529495  30000000000000000001785711        2 -59.0   865.7
# 7098  1581079398532813  30000000000000000001785C11        2 -52.0   865.7
# 7099  1581079398534187  30000000000000000001788511        2 -52.5   865.7
# 7100  1581079398551531              24539000386811        2 -71.0   865.7
# 7101  1581079398561296  30000000000000000001788511        2 -52.5   865.7
# 7102  1581079398562416  30000000000000000001785711        2 -59.0   865.7
# 7103  1581079398566433  30000000000000000001785C11        2 -52.0   865.7
# 7104  1581079398576886              24539000386811        2 -71.0   865.7
# 7105  1581079398611814  30000000000000000001785C11        3 -50.0   865.7
# 7106  1581079398613178              24539000386811        3 -66.0   865.7
# 7107  1581079398614263  30000000000000000001785A11        3 -62.5   865.7
# 7108  1581079398633793  30000000000000000001786111        3 -65.0   865.7
# 7109  1581079398650747              24539000386811        3 -66.0   865.7
# 7110  1581079398655299  30000000000000000001785A11        3 -63.0   865.7
# 7111  1581079398656794  30000000000000000001785C11        3 -50.0   865.7
# 7112  1581079398670080  30000000000000000001786111        3 -65.0   865.7
# 7113  1581079398703057  30000000000000000001785C11        4 -51.0   865.7
# 7114  1581079398704521  30000000000000000001785711        4 -59.5   865.7
# 7115  1581079398732003  30000000000000000001785C11        4 -51.0   865.7
# 7116  1581079398735589  30000000000000000001785711        4 -58.5   865.7
# 7117  1581079398882154  30000000000000000001785C11        1 -54.5   865.7
# 7118  1581079398883269              24539000386611        1 -67.5   865.7
# 7119  1581079398910926              24539000386611        1 -67.0   865.7
# 7120  1581079398912860  30000000000000000001785C11        1 -54.5   865.7
# 7121  1581079398944374  30000000000000000001788511        2 -52.5   865.7
# 7122  1581079398949302  30000000000000000001785711        2 -59.0   865.7
#
#             Adress
# 1     192.168.0.10
# 2     192.168.0.10
# 3     192.168.0.10
# 4     192.168.0.10
# 5     192.168.0.10
# 6     192.168.0.10
# 7     192.168.0.10
# 8     192.168.0.10
# 9     192.168.0.10
# 10    192.168.0.10
# 11    192.168.0.10
# 12    192.168.0.10
# 13    192.168.0.10
# 14    192.168.0.10
# 15    192.168.0.10
# 16    192.168.0.10
# 17    192.168.0.10
# 18    192.168.0.10
# 19    192.168.0.10
# 20    192.168.0.10
# 21    192.168.0.10
# 22    192.168.0.10
# 23    192.168.0.10
# 24    192.168.0.10
# 25    192.168.0.10
# 26    192.168.0.10
# 27    192.168.0.10
# 28    192.168.0.10
# 29    192.168.0.10
# 30    192.168.0.10
# ...            ...
# 7093  192.168.0.10
# 7094  192.168.0.10
# 7095  192.168.0.10
# 7096  192.168.0.10
# 7097  192.168.0.10
# 7098  192.168.0.10
# 7099  192.168.0.10
# 7100  192.168.0.10
# 7101  192.168.0.10
# 7102  192.168.0.10
# 7103  192.168.0.10
# 7104  192.168.0.10
# 7105  192.168.0.10
# 7106  192.168.0.10
# 7107  192.168.0.10
# 7108  192.168.0.10
# 7109  192.168.0.10
# 7110  192.168.0.10
# 7111  192.168.0.10
# 7112  192.168.0.10
# 7113  192.168.0.10
# 7114  192.168.0.10
# 7115  192.168.0.10
# 7116  192.168.0.10
# 7117  192.168.0.10
# 7118  192.168.0.10
# 7119  192.168.0.10
# 7120  192.168.0.10
# 7121  192.168.0.10
# 7122  192.168.0.10
#
# [7122 rows x 6 columns]

# %% [markdown]
# ### Export Data
# Nous allons sauvegarder les donées dans un fichier .csv

# %%
import time
def exportData(data, path):
    data.to_csv(path, index = None, header=False)

# %%
#tm = time.strftime("%Y-%b-%d-%H_%M_%S")
path='../2-TransformedData/p30_.csv'
exportData(dataSet, path)
