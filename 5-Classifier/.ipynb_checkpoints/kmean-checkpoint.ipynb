# %% [markdown]
# ### Import librairies
# Nous importons les bibliothèque fondamentale pour la programme

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import donnée
# Nous allons importer les données des trainSet et testSet dans les features et la variable à déviner

# %%
def importData(path):
    columnNames=["ECP","RC","MIN","MAX","MEAN","START","END","DURATION","CV","A1","A2","A3","A4","FP"]
    #columnNames=["RC","MIN","MAX","MEAN","START","END","DURATION","CV","A1","A2","A3","A4","FP"]
    delimit=','
    data = pd.read_csv(path, names=columnNames, sep=delimit)
    #data = data.drop(columns="ECP")
    return data

# %%
pathTrain='../3-DataSet/dataFinale/p27/dataSet_p27.csv'
#pathTrain='../3-DataSet/20200122/95/trainSets95.csv'
trainSet = importData(pathTrain)

trainSet.head(10)
# Out:
#                           ECP  RC   MIN   MAX       MEAN             START  \
# 0  1007CEA7AC1F3681EAC5106D36   8 -62.5 -49.0 -56.500000  1581421000726895
# 1  1007CEA7AC1F3681EAC5106D37   6 -62.5 -58.0 -59.750000  1581420723173116
# 2  1007CEA7AC1F3681EAC5106D38   6 -60.5 -47.0 -52.833333  1581420861482387
# 3  1007CEA7AC1F3681EAC5106D39   4 -53.0 -44.5 -48.250000  1581420245043182
# 4  1007CEA7AC1F3681EAC5106D40   2 -59.5 -59.5 -59.500000  1581420348861866
# 5  1007CEA7AC1F3681EAC5106D41   6 -55.5 -46.0 -50.583333  1581420091739199
# 6  1007CEA7AC1F3681EAC5106D42   2 -58.5 -56.0 -57.250000  1581419599357755
# 7  1007CEA7AC1F3681EAC5106D43   1 -61.0 -61.0 -61.000000  1581419911688374
# 8  1007CEA7AC1F3681EAC5106D44   6 -61.5 -56.0 -59.416667  1581419755370087
# 9  1007CEA7AC1F3681EAC5106D45   8 -64.0 -49.5 -56.562500  1581414802681020
#
#                 END  DURATION        CV  A1  A2  A3  A4  FP
# 0  1581421002835828   2108933 -0.093655   8   0   0   0   0
# 1  1581420724051659    878543 -0.033034   6   0   0   0   0
# 2  1581420862949611   1467224 -0.090882   6   0   0   0   0
# 3  1581420245948951    905769 -0.064090   4   0   0   0   0
# 4  1581420348898056     36190 -0.000000   2   0   0   0   0
# 5  1581420092980854   1241655 -0.066165   6   0   0   0   0
# 6  1581419599579068    221313 -0.021834   0   0   2   0   0
# 7  1581419911688374         0 -0.000000   1   0   0   0   0
# 8  1581419756524144   1154057 -0.033455   2   0   4   0   0
# 9  1581414804509899   1828879 -0.086548   8   0   0   0   0

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 500
x = trainSet['MEAN']
y = trainSet['MAX']
colors = (0,0,0)
area = np.pi*3

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ### Import plot librairie
# Il est temps de voir comment les élements X et FP sont liées les uns aux autres avec un graphe

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

g = sns.FacetGrid(trainSet, col='FP')
g.map(plt.hist, 'MAX', bins=20)

# %% [markdown]
# ### Split Data
# Nous allons découper les données d'apprentissage pour avoir la partie feature et y

# %%
#features=trainSet.loc[:,'RC':'A4']
X = np.array(trainSet.iloc[:,1:-1]).astype(int)
y = np.array(trainSet['FP'])
print(X.shape)
print(trainSet.shape)
print(y.shape)
# Out:
# (1129, 12)
# (1129, 14)
# (1129,)

# %% [markdown]
# ### Normalize Data
# Nous allons

# %%
from sklearn import preprocessing
X = preprocessing.normalize(X)

# %%
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('wcss')
plt.show()

# %% [markdown]
# ### Trainning
# Nous allons

# %%
k=2
#from sklearn.preprocessing import LabelEncoder
#from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=k, max_iter=600, algorithm = 'auto')
kmeans.fit(X)
#y_kmeans=kmeans.fit_predict(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=600,
#     n_clusters=2, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
correct = 0
for i in range(len(X)):
    predict_me = np.array(X[i].astype(float))
    predict_me = predict_me.reshape(-1, len(predict_me))
    prediction = kmeans.predict(predict_me)
    if prediction[0] == y[i]:
        correct += 1

print("Score: ", correct/len(X))
# Out:
# Score:  0.941541186891054

# %%
y_pred = kmeans.predict(X)
predict_data=trainSet
predict_data['IS_FP']=y_pred

predict_data.head(50)
# Out:
#                              ECP  RC   MIN   MAX       MEAN             START  \
# 0     1007CEA7AC1F3681EAC5106D21   6 -57.0 -49.5 -53.500000  1581420973274508
# 1     1007CEA7AC1F3681EAC5106D22   1 -62.0 -62.0 -62.000000  1581420688744448
# 2     1007CEA7AC1F3681EAC5106D23   6 -56.0 -48.5 -53.083333  1581420883774374
# 3     1007CEA7AC1F3681EAC5106D25   4 -54.0 -45.0 -48.875000  1581420217848224
# 4     1007CEA7AC1F3681EAC5106D26   7 -60.0 -45.0 -51.571429  1581420117430720
# 5     1007CEA7AC1F3681EAC5106D29   2 -59.5 -58.5 -59.000000  1581419787766006
# 6     1007CEA7AC1F3681EAC5106D30   1 -60.0 -60.0 -60.000000  1581414773721288
# 7     1007CEA7AC1F3681EAC5106D31   8 -59.5 -53.5 -56.500000  1581415046776906
# 8     1007CEA7AC1F3681EAC5106D32   8 -54.0 -39.0 -47.562500  1581414922500972
# 9     1007CEA7AC1F3681EAC5106D33  16 -60.0 -50.0 -55.781250  1581414578916990
# 10    1007CEA7AC1F3681EAC5106D35  10 -57.5 -53.0 -55.050000  1581414354017999
# 11    1007CEA7AC1F3681EAC5106D67   2 -61.0 -59.0 -60.000000  1581427758469887
# 12    1007CEA7AC1F3681EAC5106D68   2 -56.0 -55.5 -55.750000  1581427698904057
# 13  1007CEA7AC1F3681EAC5106D6869   3 -60.0 -57.5 -58.333333  1581427723894491
# 14    1007CEA7AC1F3681EAC5106D71   4 -56.0 -53.0 -54.250000  1581427320589171
# 15    1007CEA7AC1F3681EAC5106D72   3 -58.5 -56.0 -57.333333  1581427388512493
# 16    1007CEA7AC1F3681EAC5106D76   1 -55.5 -55.5 -55.500000  1581429726150532
# 17    1007CEA7AC1F3681EAC5106D77   6 -58.0 -53.0 -55.166667  1581426776296180
# 18    1007CEA7AC1F3681EC88046821   6 -60.0 -51.5 -55.916667  1581420973775390
# 19    1007CEA7AC1F3681EC88046823   4 -59.0 -53.0 -56.500000  1581420884458898
# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score

def printCv(clf, xFeatures, y_true, size):
    print("Cross validation: \n",cross_val_score(clf, xFeatures, y_true, cv=5))

def printMetrics(y, y_pred):
    print("Confusion Matrix\n",metrics.confusion_matrix(y, y_pred))
    print("Accuracy: ", metrics.accuracy_score(y, y_pred))
    print("Ajusted Rand Square",metrics.adjusted_rand_score(y, y_pred))
      
printMetrics(y,y_pred)
predict_data['crossValid'] = cross_val_score(kmeans, X, y, cv=len(trainSet))
# Out:
# Confusion Matrix
#  [[1063   20]
#  [  46    0]]
# Accuracy:  0.941541186891
# Ajusted Rand Square -0.0237948875764

# %%
centroids = kmeans.cluster_centers_

#plt.figure(figsize=(8, 6))
for i in range(len(X)):
    #print(trainSet.iloc[i][1])
    plt.plot(X[i][6], X[i][7], colors[y_pred[i]], markersize = 5)
    

#plt.scatter(centroids[:, 0],centroids[:, 1], marker = "x", s=50, linewidths = 5, zorder = 10,c='black')
plt.legend()
plt.show()

# %%
#LoadData
path='../2-TransformedData/testSet_2020-Jan-29-21_10_32.csv'

#path='../2-TransformedData/data2_2020-Jan-31-10_55_51.csv'
#toPredict = pd.read_csv(path,names=["RC","MIN","MAX","MEAN","START","END","DURATION","CV","A1","A2","A3","A4"], sep=',')
#XFeature = np.array(toPredict).astype(int)

toPredict = pd.read_csv(path,names=["ECP","RC","MIN","MAX","MEAN","START","END","DURATION","CV","A1","A2","A3","A4","FP"], sep=',')

XFeature = np.array(toPredict.loc[:,'RC':'A4']).astype(int)
XFeature = preprocessing.normalize(XFeature)
y_p = kmeans.predict(XFeature)

toPredict['IS_FP']=y_p

toPredict
# Out:
#                          ECP   RC   MIN   MAX       MEAN             START  \
# 0               245390003868  210 -67.0 -58.5 -61.957143  1579699702957564
# 1               245390003869  174 -63.0 -56.5 -60.583333  1579699702975300
# 2   300000000000000000017856    1 -63.5 -63.5 -63.500000  1579699733327556
# 3   300000000000000000017857  304 -63.5 -56.0 -57.626645  1579699703039548
# 4   300000000000000000017858    1 -57.5 -57.5 -57.500000  1579699717786689
# 5   30000000000000000001785C  287 -58.5 -53.0 -54.932056  1579699702951407
# 6   30000000000000000001785D  309 -64.5 -58.0 -61.085761  1579699703042235
# 7   30000000000000000001785E    4 -60.0 -58.5 -59.500000  1579699713693963
# 8   300000000000000000017862   11 -60.5 -54.0 -57.000000  1579699710512550
# 9   300000000000000000017863   18 -60.5 -52.5 -57.305556  1579699731195273
# 10  300000000000000000017864   10 -65.5 -61.5 -64.000000  1579699731905611
# 11  300000000000000000017868   30 -64.0 -56.0 -60.350000  1579699731618532
# 12  30000000000000000001786A   34 -63.0 -55.0 -58.794118  1579699731882005
# 13  30000000000000000001786E    2 -55.5 -55.5 -55.500000  1579699732938086
# 14  30000000000000000001786F   10 -64.5 -60.0 -62.600000  1579699731275397
# 15  300000000000000000017870    2 -64.5 -64.0 -64.250000  1579699715951015
# 16  300000000000000000017871   11 -65.0 -60.5 -63.363636  1579699714393952
# 17  300000000000000000017872    8 -64.5 -58.0 -61.625000  1579699714914925
# 18  300000000000000000017873    4 -65.5 -62.5 -63.875000  1579699715606290
# 19  300000000000000000017874   10 -65.5 -59.5 -62.600000  1579699715338071
# 20  300000000000000000017875   17 -64.5 -57.5 -61.970588  1579699714132503
# 21  300000000000000000017877    4 -59.0 -53.5 -55.875000  1579699714853311
# 22  300000000000000000017878   30 -63.0 -54.0 -57.966667  1579699712323457
# 23  300000000000000000017879    2 -65.5 -65.0 -65.250000  1579699716558777
# 24  300000000000000000017882  644 -63.5 -53.0 -57.243012  1579699702897021
# 25  3000000000000000000178BD   25 -64.0 -55.0 -58.760000  1579699713996403
#
#                  END  DURATION        CV  A1   A2   A3   A4  FP  IS_FP
# 0   1579699747867390  44909826 -0.020082   7    5  198    0   1      1
# 1   1579699745158768  42183468 -0.016437   0    0  173    1   1      0
# 2   1579699733327556         0 -0.000000   0    1    0    0   1      0
# 3   1579699747950958  44911410 -0.015811   0    2    1  301   1      2
# 4   1579699717786689         0 -0.000000   0    0    1    0   1      0
# 5   1579699745675824  42724417 -0.017785   3    0  284    0   1      2
# 6   1579699748151155  45108920 -0.014276   2   11    0  296   1      2
# 7   1579699714336538    642575 -0.010292   4    0    0    0   0      0
# 8   1579699715069601   4557051 -0.036071   5    0    6    0   0      0
# 9   1579699733021167   1825894 -0.037713   0   10    0    8   0      0
# 10  1579699733439142   1533531 -0.020071   5    2    3    0   0      0
# 11  1579699733899709   2281177 -0.037368  12   12    4    2   0      0
# 12  1579699734139726   2257721 -0.034705  10   14   10    0   0      0
# 13  1579699732983936     45850 -0.000000   0    2    0    0   0      0
# 14  1579699733901682   2626285 -0.027852   7    1    0    2   0      0
# 15  1579699716017444     66429 -0.003891   0    0    2    0   0      0
# 16  1579699717039111   2645159 -0.024517   0    2    2    7   0      0
# 17  1579699715981860   1066935 -0.033144   0    0    3    5   0      0
# 18  1579699716004159    397869 -0.018668   0    0    4    0   0      0
# 19  1579699716955089   1617018 -0.031099   2    1    3    4   0      1
# 20  1579699716729005   2596502 -0.038592   4    3    9    1   0      0
# 21  1579699715451231    597920 -0.040206   2    0    2    0   0      0
# 22  1579699716183486   3860029 -0.046500   9    8    1   12   0      0
# 23  1579699716587445     28668 -0.003831   0    2    0    0   0      0
# 24  1579699748054137  45157116 -0.030216  28  301    6  309   1      0
# 25  1579699716641124   2644721 -0.044386  12    4    5    4   0      0

# %%
#Export predict data
pathExport='../6-ClassifiedData/20200217kmeans_predict.csv'
predict_data.to_csv(pathExport, index = None, header=True)
