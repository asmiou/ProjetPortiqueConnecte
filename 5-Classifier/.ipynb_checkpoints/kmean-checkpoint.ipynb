# %% [markdown]
# ### Import librairies
# Nous importons les bibliothèque fondamentale pour la programme

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import donnée
# Nous allons importer les données des trainSet et testSet dans les features et la variable à déviner

# %%
def importData(path):
    #columnNames=["ECP","RC","MIN","MAX","MEAN","START","END","DURATION","CV","A1","A2","A3","A4","FP"]
    columnNames=["RC","MIN","MAX","MEAN","START","END","DURATION","CV","A1","A2","A3","A4","FP"]
    delimit=','
    data = pd.read_csv(path, names=columnNames, sep=delimit)
    #data = data.drop(columns="ECP")
    return data

# %%
pathTrain='../2-TransformedData/export_2020-Jan-28-17_01_12.csv'
data = importData(pathTrain)

data.head(2)
# Out:
#                RC   MIN   MAX       MEAN             START               END  \
# 245390003868  210 -67.0 -58.5 -61.957143  1579699702957564  1579699747867390
# 245390003869  174 -63.0 -56.5 -60.583333  1579699702975300  1579699745158768
#
#               DURATION        CV  A1  A2   A3  A4  FP
# 245390003868  44909826 -0.020082   7   5  198   0   1
# 245390003869  42183468 -0.016437   0   0  173   1   1

# %%
#trainSet['RC']=data['RC']
#trainSet['START']=data['START']
#trainSet['END']=data['END']
trainSet['FP']=data['FP']

trainSet['MIN']=data['MIN']
trainSet['MAX']=data['MAX']
trainSet['MIN']=data['MIN']
trainSet['DURATION']=data['DURATION']
trainSet['CV']=data['CV']
trainSet['A1']=data['A1']
trainSet['A2']=data['A2']
trainSet['A3']=data['A3']
trainSet['A4']=data['A4']
trainSet.head(5)
# Out:
#                            RC   MIN   MAX       MEAN             START  \
# 245390003868              210 -67.0 -58.5 -61.957143  1579699702957564
# 245390003869              174 -63.0 -56.5 -60.583333  1579699702975300
# 300000000000000000017856    1 -63.5 -63.5 -63.500000  1579699733327556
# 300000000000000000017857  304 -63.5 -56.0 -57.626645  1579699703039548
# 300000000000000000017858    1 -57.5 -57.5 -57.500000  1579699717786689
#
#                                        END  DURATION        CV  A1  A2   A3  \
# 245390003868              1579699747867390  44909826 -0.020082   7   5  198
# 245390003869              1579699745158768  42183468 -0.016437   0   0  173
# 300000000000000000017856  1579699733327556         0 -0.000000   0   1    0
# 300000000000000000017857  1579699747950958  44911410 -0.015811   0   2    1
# 300000000000000000017858  1579699717786689         0 -0.000000   0   0    1
#
#                            A4  FP  IS_FP
# 245390003868                0   1      1
# 245390003869                1   1      1
# 300000000000000000017856    0   1      0
# 300000000000000000017857  301   1      1
# 300000000000000000017858    0   1      0

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 500
x = trainSet['MEAN']
y = trainSet['MAX']
colors = (0,0,0)
area = np.pi*3

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ### Import plot librairie
# Il est temps de voir comment les élements X et FP sont liées les uns aux autres avec un graphe

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

g = sns.FacetGrid(trainSet, col='FP')
g.map(plt.hist, 'MAX', bins=20)

# %% [markdown]
# ### Split Data
# Nous allons découper les données d'apprentissage pour avoir la partie feature et y

# %%
#features=trainSet.loc[:,'RC':'A4']
X = np.array(trainSet.iloc[:-1]).astype(int)
y = np.array(trainSet['FP'])

# %% [markdown]
# ### Normalize Data
# Nous allons

# %%
from sklearn import preprocessing
X = preprocessing.normalize(X)

# %%
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('wcss')
plt.show()

# %% [markdown]
# ### Trainning
# Nous allons

# %%
k=2
#from sklearn.preprocessing import LabelEncoder
#from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=k, max_iter=600, algorithm = 'auto')
kmeans.fit(X)
#y_kmeans=kmeans.fit_predict(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=600,
#     n_clusters=2, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
correct = 0
for i in range(len(X)):
    predict_me = np.array(X[i].astype(float))
    predict_me = predict_me.reshape(-1, len(predict_me))
    prediction = kmeans.predict(predict_me)
    if prediction[0] == y[i]:
        correct += 1

print("Score: ", correct/len(X))
# Out:
# Score:  0.9230769230769231

# %%
y_pred = kmeans.predict(X)
predict_data=trainSet
predict_data['IS_FP']=y_pred

predict_data
# Out:
#                            RC   MIN   MAX       MEAN             START  \
# 245390003868              210 -67.0 -58.5 -61.957143  1579699702957564
# 245390003869              174 -63.0 -56.5 -60.583333  1579699702975300
# 300000000000000000017856    1 -63.5 -63.5 -63.500000  1579699733327556
# 300000000000000000017857  304 -63.5 -56.0 -57.626645  1579699703039548
# 300000000000000000017858    1 -57.5 -57.5 -57.500000  1579699717786689
# 30000000000000000001785C  287 -58.5 -53.0 -54.932056  1579699702951407
# 30000000000000000001785D  309 -64.5 -58.0 -61.085761  1579699703042235
# 30000000000000000001785E    4 -60.0 -58.5 -59.500000  1579699713693963
# 300000000000000000017862   11 -60.5 -54.0 -57.000000  1579699710512550
# 300000000000000000017863   18 -60.5 -52.5 -57.305556  1579699731195273
# 300000000000000000017864   10 -65.5 -61.5 -64.000000  1579699731905611
# 300000000000000000017868   30 -64.0 -56.0 -60.350000  1579699731618532
# 30000000000000000001786A   34 -63.0 -55.0 -58.794118  1579699731882005
# 30000000000000000001786E    2 -55.5 -55.5 -55.500000  1579699732938086
# 30000000000000000001786F   10 -64.5 -60.0 -62.600000  1579699731275397
# 300000000000000000017870    2 -64.5 -64.0 -64.250000  1579699715951015
# 300000000000000000017871   11 -65.0 -60.5 -63.363636  1579699714393952
# 300000000000000000017872    8 -64.5 -58.0 -61.625000  1579699714914925
# 300000000000000000017873    4 -65.5 -62.5 -63.875000  1579699715606290
# 300000000000000000017874   10 -65.5 -59.5 -62.600000  1579699715338071
# 300000000000000000017875   17 -64.5 -57.5 -61.970588  1579699714132503
# 300000000000000000017877    4 -59.0 -53.5 -55.875000  1579699714853311
# 300000000000000000017878   30 -63.0 -54.0 -57.966667  1579699712323457
# 300000000000000000017879    2 -65.5 -65.0 -65.250000  1579699716558777
# 300000000000000000017882  644 -63.5 -53.0 -57.243012  1579699702897021
# 3000000000000000000178BD   25 -64.0 -55.0 -58.760000  1579699713996403
#
#                                        END  DURATION        CV  A1   A2   A3  \
# 245390003868              1579699747867390  44909826 -0.020082   7    5  198
# 245390003869              1579699745158768  42183468 -0.016437   0    0  173
# 300000000000000000017856  1579699733327556         0 -0.000000   0    1    0
# 300000000000000000017857  1579699747950958  44911410 -0.015811   0    2    1
# 300000000000000000017858  1579699717786689         0 -0.000000   0    0    1
# 30000000000000000001785C  1579699745675824  42724417 -0.017785   3    0  284
# 30000000000000000001785D  1579699748151155  45108920 -0.014276   2   11    0
# 30000000000000000001785E  1579699714336538    642575 -0.010292   4    0    0
# 300000000000000000017862  1579699715069601   4557051 -0.036071   5    0    6
# 300000000000000000017863  1579699733021167   1825894 -0.037713   0   10    0
# 300000000000000000017864  1579699733439142   1533531 -0.020071   5    2    3
# 300000000000000000017868  1579699733899709   2281177 -0.037368  12   12    4
# 30000000000000000001786A  1579699734139726   2257721 -0.034705  10   14   10
# 30000000000000000001786E  1579699732983936     45850 -0.000000   0    2    0
# 30000000000000000001786F  1579699733901682   2626285 -0.027852   7    1    0
# 300000000000000000017870  1579699716017444     66429 -0.003891   0    0    2
# 300000000000000000017871  1579699717039111   2645159 -0.024517   0    2    2
# 300000000000000000017872  1579699715981860   1066935 -0.033144   0    0    3
# 300000000000000000017873  1579699716004159    397869 -0.018668   0    0    4
# 300000000000000000017874  1579699716955089   1617018 -0.031099   2    1    3
# 300000000000000000017875  1579699716729005   2596502 -0.038592   4    3    9
# 300000000000000000017877  1579699715451231    597920 -0.040206   2    0    2
# 300000000000000000017878  1579699716183486   3860029 -0.046500   9    8    1
# 300000000000000000017879  1579699716587445     28668 -0.003831   0    2    0
# 300000000000000000017882  1579699748054137  45157116 -0.030216  28  301    6
# 3000000000000000000178BD  1579699716641124   2644721 -0.044386  12    4    5
#
#                            A4  FP  IS_FP
# 245390003868                0   1      1
# 245390003869                1   1      1
# 300000000000000000017856    0   1      0
# 300000000000000000017857  301   1      1
# 300000000000000000017858    0   1      0
# 30000000000000000001785C    0   1      1
# 30000000000000000001785D  296   1      1
# 30000000000000000001785E    0   0      0
# 300000000000000000017862    0   0      0
# 300000000000000000017863    8   0      0
# 300000000000000000017864    0   0      0
# 300000000000000000017868    2   0      0
# 30000000000000000001786A    0   0      0
# 30000000000000000001786E    0   0      0
# 30000000000000000001786F    2   0      0
# 300000000000000000017870    0   0      0
# 300000000000000000017871    7   0      0
# 300000000000000000017872    5   0      0
# 300000000000000000017873    0   0      0
# 300000000000000000017874    4   0      0
# 300000000000000000017875    1   0      0
# 300000000000000000017877    0   0      0
# 300000000000000000017878   12   0      0
# 300000000000000000017879    0   0      0
# 300000000000000000017882  309   1      1
# 3000000000000000000178BD    4   0      0

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score

def printCv(clf, xFeatures, y, size):
    print("Cross validation: \n",cross_val_score(clf, xFeatures, y, cv=5))

def printMetrics(y, y_pred):
    print("Confusion Matrix\n",metrics.confusion_matrix(y, y_pred))
    print("Accuracy: ", metrics.accuracy_score(y, y_pred))
    print("Ajusted Rand Square",metrics.adjusted_rand_score(y, y_pred))
    
printMetrics(y,y_pred)
# Out:
# Confusion Matrix
#  [[18  0]
#  [ 2  6]]
# Accuracy:  0.923076923077
# Ajusted Rand Square 0.695550351288

# %%
centroids = kmeans.cluster_centers_

#plt.figure(figsize=(8, 6))
for i in range(len(X)):
    #print(trainSet.iloc[i][1])
    plt.plot(X[i][6], X[i][7], colors[y_pred[i]], markersize = 5)
    

#plt.scatter(centroids[:, 0],centroids[:, 1], marker = "x", s=50, linewidths = 5, zorder = 10,c='black')
plt.legend()
plt.show()

# %%
#LoadData
path='../2-TransformedData/testSet_2020-Jan-29-21_10_32.csv'

#path='../2-TransformedData/data2_2020-Jan-31-10_55_51.csv'
#toPredict = pd.read_csv(path,names=["RC","MIN","MAX","MEAN","START","END","DURATION","CV","A1","A2","A3","A4"], sep=',')
#XFeature = np.array(toPredict).astype(int)

toPredict = pd.read_csv(path,names=["ECP","RC","MIN","MAX","MEAN","START","END","DURATION","CV","A1","A2","A3","A4","FP"], sep=',')

XFeature = np.array(toPredict.loc[:,'RC':'A4']).astype(int)
XFeature = preprocessing.normalize(XFeature)
y_p = kmeans.predict(XFeature)

toPredict['IS_FP']=y_p

toPredict
# Out:
#                          ECP   RC   MIN   MAX       MEAN             START  \
# 0               245390003868  210 -67.0 -58.5 -61.957143  1579699702957564
# 1               245390003869  174 -63.0 -56.5 -60.583333  1579699702975300
# 2   300000000000000000017856    1 -63.5 -63.5 -63.500000  1579699733327556
# 3   300000000000000000017857  304 -63.5 -56.0 -57.626645  1579699703039548
# 4   300000000000000000017858    1 -57.5 -57.5 -57.500000  1579699717786689
# 5   30000000000000000001785C  287 -58.5 -53.0 -54.932056  1579699702951407
# 6   30000000000000000001785D  309 -64.5 -58.0 -61.085761  1579699703042235
