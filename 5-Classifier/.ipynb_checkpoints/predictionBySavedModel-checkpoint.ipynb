# %% [markdown]
# ### Import librairies
# Nous importons les bibliothèque fondamentale pour la programme

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###  Load Data
# Nous allons importer les données des trainSet et testSet dans les features et la variable à déviner

# %%
path='../3-DataSet/dataFinale/p25/testSet_p25.csv'
#path='../3-DataSet/dataFinale/p27/testSet_p27.csv'
#path='../3-DataSet/dataFinale/p230/testSet_p30.csv'

#cols=["ECP","RC","MIN","MAX","MEAN","START","END","DURATION","CV","A1","A2","A3","A4"]
cols=["ECP","RC","MIN","MAX","MEAN","START","END","DURATION","CV","A1","A2","A3","A4","FP"]
toPredict = pd.read_csv(path,names=cols, sep=',')
toPredict.head(5)
# Out:
#                           ECP  RC   MIN   MAX       MEAN             START  \
# 0  3005FB63AC1F3681EC8815B921   9 -58.5 -52.0 -56.555556  1581420973596918
# 1  E2806890000000001834376767   2 -63.0 -62.0 -62.500000  1581427757606159
# 2  E2806890000000001834531777  66 -63.5 -58.0 -60.045455  1581426772161856
# 3  2005FB63EAC13681E4EC0FD224   4 -65.0 -59.0 -62.000000  1581420375415960
# 4  3005FB63AC1F3681EC88142830   7 -57.5 -45.0 -50.928571  1581414771515647
#
#                 END  DURATION        CV  A1  A2  A3  A4  FP
# 0  1581420974726948   1130030 -0.040071   3   0   6   0   0
# 1  1581427757711480    105321 -0.008000   0   0   2   0   0
# 2  1581426781271598   9109742 -0.016888  66   0   0   0   1
# 3  1581420375804651    388691 -0.038253   0   4   0   0   0
# 4  1581414773005717   1490070 -0.087408   7   0   0   0   0

# %% [markdown]
# ### Normalisation et mise en echelle
# Avant de faire des prédictions réelles, il est toujours recommandé de mettre à l'échelle les entités afin que toutes puissent être évaluées uniformément.
# L'algorithme de descente de gradient (qui est utilisé dans la formation de réseaux de neurones et d'autres algorithmes d'apprentissage automatique) converge également plus rapidement avec des fonctionnalités normalisées.
# ![](scaling.JPG)

# %%
from sklearn.preprocessing import StandardScaler

def scaleData(data):
    scaler = StandardScaler()
    scaler.fit(data)
    return scaler.transform(data)

# %%
X_toPredict = scaleData(toPredict.loc[:,'RC':'A4'])
y_toPredict = toPredict['FP']

# %% [markdown]
# ### Load models and Predict
# Nous allons charger les différents models enregistrés puis predire les données avec chacun des models

# %%
import pickle

#modelFilename = 'logreg_Model.sav'
m#odel = pickle.load(open(logregFilename, 'rb'))

modelFilename = 'knn_Model.sav'
model = pickle.load(open(knnFilename, 'rb'))

#modelFilename = 'gaussianSVC_Model.sav'
#model = pickle.load(open(svmFilename, 'rb'))

# %% [markdown]
# ### Evaluation
# Pour évaluer un algorithme, la matrice de confusion, la précision, le rappel et le score f1 sont les mesures les plus couramment utilisées. Les méthodes confusion_matrixet classification_reportde sklearn.metricspeuvent être utilisées pour calculer ces métriques. Jetez un œil au script suivant:

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics

def showConfusionMatrix(ytest,ypred):
    print("Confusion Matrix \n",confusion_matrix(ytest, ypred))
    print("Repport: \n",classification_report(ytest, ypred))
    
def printMetrics(yTest, yPred):
    print("Accuracy: ", metrics.accuracy_score(yTest, yPred))
    print("Ajusted Rand Square",metrics.adjusted_rand_score(yTest, yPred))

# %% [markdown]
# ### Prediction

# %%
### Logistic Regression
#pred = model.predict(X_toPredict)

#showConfusionMatrix(y_toPredict,pred)
#printMetrics(y_toPredict, pred)

# %%
#Knn Predict
pred = model.predict(X_toPredict)

showConfusionMatrix(y_toPredict,pred)
printMetrics(y_toPredict, pred)
# Out:
# Confusion Matrix
#  [[217   1]
#  [  2   6]]
# Repport:
#               precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99       218
#           1       0.86      0.75      0.80         8
#
# avg / total       0.99      0.99      0.99       226
#
# Accuracy:  0.986725663717
# Ajusted Rand Square 0.781849563568

# %%
#SVM Gaussien
#svm_pred = svmModel.predict(X_toPredict)

#showConfusionMatrix(y_toPredict,svm_pred)
#printMetrics(y_toPredict, svm_pred)

# %% [markdown]
# ### Build DataSet

# %%
toPredict['IS_FP']=logreg_pred
print(toPredict.shape)
toPredict.tail(50)
# Out:
# (226, 17)
#                               ECP  RC   MIN   MAX       MEAN  \
# 176    3005FB63AC1F3681EC88155C32   7 -63.0 -45.5 -51.285714
# 177  1532FB63AC1F3681EC8804686869   7 -60.0 -46.5 -52.214286
# 178    1007CEA7AC1F3681EC88046874  10 -61.5 -53.0 -57.050000
# 179    7336CEF1C1FE3682DEA1005C67   1 -57.5 -57.5 -57.500000
# 180    2005FB63EAC13681E4EC0F5070   5 -62.5 -58.5 -60.700000
# 181    2005FB63AC1F3681AB1004E373  10 -60.5 -53.5 -56.400000
# 182    7336CEF1C1FE3682DEA1005C33   4 -57.5 -56.5 -57.125000
# 183    3005FB63AC1F3681EC8805AA25   3 -58.0 -54.5 -56.000000
# 184    E280689000000000183444A670   3 -65.5 -63.5 -64.666667
# 185    3005FB63AC1F3681EC88145130   3 -54.0 -50.0 -52.000000
# 186    3005FB63AC1F3681EC8815B935   8 -56.5 -51.5 -53.625000
# 187    E2806890000000001834376067   2 -66.0 -63.0 -64.500000
# 188    1007CEA7AC1F3681EAC5106D25   4 -54.0 -45.0 -48.875000
# 189    E2806890000000001834531772  61 -62.5 -58.0 -59.778689
# 190    3005FB63AC1F3681EC88145829   4 -56.5 -52.5 -54.375000
# 191    E28068900000000018345CD576   4 -71.5 -67.5 -69.375000
# 192    3005FB63AC1F3681EC8814C177   9 -62.0 -52.5 -57.888889
# 193  90134BC1F1CE3781AEA100106869   2 -56.0 -55.0 -55.500000
# 194  7336CEF1C1FE3682DEA1004B6869   2 -62.5 -61.5 -62.000000
# 195    7336CEF1C1FE3682DEA1005170   2 -59.5 -59.5 -59.500000
# 196    3005FB63AC1F3681EC88155C74   4 -56.5 -55.0 -55.875000
# 197    2005FB63AC1F3681AB10052A27   7 -60.0 -53.0 -56.571429
# 198    90144BC1F1CE3681EA88081133   6 -62.0 -56.5 -59.000000
# 199    3005FB63AC1F3681EC88145A32   6 -58.0 -44.0 -49.583333
# 200    2005FB63AC1F3681AB10052A68   4 -55.0 -54.0 -54.250000
# 201    E2806890000000001834362C34   1 -70.5 -70.5 -70.500000
# 202    7336CEF1C1FE3682DEA1004B74   3 -61.0 -60.0 -60.500000
# 203  7336CEF1C1FE3682DEA1004C6869   1 -57.0 -57.0 -57.000000
# 204    2005FB63EAC13681E4EC0F4B70   7 -63.0 -49.5 -58.214286
# 205    2005FB63EAC13681E4EC0FEA68   2 -53.0 -52.0 -52.500000
# 206    3005FB63AC1F3681EC88143C25   2 -60.0 -60.0 -60.000000
# 207    E2806890000000001834316C32   1 -74.0 -74.0 -74.000000
# 208    3005FB63AC1F3681EC8814BC67   2 -62.5 -58.0 -60.250000
# 203  1581427723559087  1581427723559087         0 -0.000000   0   0   1   0
# 204  1581427432926138  1581427434130908   1204770 -0.070656   2   3   2   0
# 205  1581427698913063  1581427699006535     93472 -0.009524   0   2   0   0
# 206  1581420219163307  1581420219259582     96275 -0.000000   0   0   2   0
# 207  1581414922324416  1581414922324416         0 -0.000000   0   0   0   1
# 208  1581427758462969  1581427758583388    120419 -0.037344   0   2   0   0
# 209  1581420216967673  1581420219065711   2098038 -0.030052   0   7   0   0
# 210  1581420219004518  1581420219111667    107149 -0.015385   0   2   0   0
# 211  1581427432217879  1581427433067906    850027 -0.042772   4   0   0   0
# 212  1581427432182690  1581427432327352    144662 -0.000000   2   0   0   0
# 213  1581427432172197  1581427432385062    212865 -0.025000   2   0   0   0
# 214  1581414354543572  1581414355131853    588281 -0.040709   0   0   3   0
# 215  1581427723621637  1581427724010679    389042 -0.038835   0   1   1   0
# 216  1581419786835265  1581419789005842   2170577 -0.027760   6   3   0   0
# 217  1581414922431471  1581414922996797    565326 -0.062902   3   0   0   0
# 218  1581427389000994  1581427389115265    114271 -0.000000   2   0   0   0
# 219  1581420973569859  1581420973631012     61153 -0.004082   0   0   2   0
# 220  1581429725735077  1581429725813460     78383 -0.013333   2   0   0   0
# 221  1581426581733210  1581426581808221     75011 -0.008772   2   0   0   0
# 222  1581427723966021  1581427724250206    284185 -0.013100   0   1   1   0
# 223  1581427698904057  1581427699001759     97702 -0.004484   0   2   0   0
# 224  1581414580510879  1581414580565921     55042 -0.000000   2   0   0   0
# 225  1581420375426863  1581420375778041    351178 -0.012559   0   3   0   0
#
#      FP  FP_LG  FP_KNN  FP_SVM
# 176   0      0       0       0
# 177   0      0       0       0
# 178   0      0       0       0
# 179   0      0       0       0
# 180   0      0       0       0
# 181   0      0       0       0
# 182   0      0       0       0
# 183   0      0       0       0
# 184   0      0       0       0
# 185   0      0       0       0
# 186   0      0       0       0
# 187   0      0       0       0
# 188   0      0       0       0
# 189   1      1       1       1
# 190   0      0       0       0
# 191   1      0       0       0
# 192   0      0       0       0
# 193   0      0       0       0
# 194   0      0       0       0
# 195   0      0       0       0
# 196   0      0       0       0
# 197   0      0       0       0
# 198   0      0       0       0
# 199   0      0       0       0
# 200   0      0       0       0
# 201   0      0       0       0
# 202   0      0       0       0
# 203   0      0       1       0
# 204   0      0       0       0
# 205   0      0       0       0
# 206   0      0       0       0
# 207   0      0       0       0
# 208   0      0       0       0
# 209   0      0       0       0
# 210   0      0       0       0
# 211   0      0       0       0
# 212   0      0       0       0
# 213   0      0       0       0
# 214   0      0       0       0
# 215   0      0       0       0
# 216   0      0       0       0
# 217   0      0       0       0
# 218   0      0       0       0
# 219   0      0       0       0
# 220   0      0       0       0
# 221   0      0       0       0
# 222   0      0       0       0
# 223   0      0       0       0
# 224   0      0       0       0
# 225   0      0       0       0

# %% [markdown]
# ### Evaluation

# %%
def rate(y, y_pred):
    """Return classification error of `(X, y)` with prediction `y_pred`."""
    return 100-((y != y_pred).sum() / len(y))

success = rate(toPredict['FP'], toPredict['VERDICT'])
print("Success rate: ",success)
# Out:
# Success rate:  99.9911504425

# %% [markdown]
# ### Export

# %%
pathExport='../6-ClassifiedData/predctBySavedModel_25.csv'
toPredict.to_csv(pathExport, index = None, header=True)
